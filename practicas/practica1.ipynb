# %%
import numpy as np

type array = np.ndarray

# %% [markdown]
# 21.  Utilizando solo las operaciones y funciones vistas en los ejercicios anteriores, escribir codigos de una sola linea para las siguientes funciones matematicas.

# %% [markdown]
# (a) $ \lVert v \rVert =
# \sqrt{
#     v_1^2 + \dots + v_n^2
#     } =
# \sqrt{
#     \sum_{i=1}^{n} v_i^2
#     }
#     $

# %%
def norma_2(v: array) -> float :
    return np.sqrt(np.sum(v**2))

# %% [markdown]
# (c)

# %%
def prod_interno(v, w) :
    return np.sum(v*w)
